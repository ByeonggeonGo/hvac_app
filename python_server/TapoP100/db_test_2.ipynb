# %%
import pandas as pd
import pymysql
import dask.dataframe as dd
import sqlalchemy
from sqlalchemy import create_engine

# %%
#데이터 베이스와 연결하는 부분
#mysql은 pymysql.connect를 사용하여 데이터베이스와 연결 
#user=mysql 데이터베이스 사용자 이름 , 
#passwd=mysql 데이터 베이스 비밀번호 
#host= mysql 데이터베이스 주소 
#db= 접속하려는 데이터베이스 (현재는 sensor)
conn = pymysql.connect(
user='room_test',
passwd='ehrnc64581',
#222.108.71.247(외부주소)
host='222.108.71.247',
#7656(외부포트)
port=7656,
db='sensor',
)

#TEST
# sql="SELECT * FROM data WHERE 날짜 > now() - INTERVAL 1 DAY;"

# 5분데이터 불러오는 부분
# sql="SELECT * FROM data WHERE 센서번호=01 AND 날짜 > now() - INTERVAL 5 MINUTE;"

#10분데이터 불러오는 부분
#selcet 원하는 칼럽 from 테이블이름(ex:sensor_44~sensor52) where(조건문) 원하는 조건(ex: 날짜 > now() - INTERVAL 10 MINUTE)
sql="SELECT * FROM sensor_45 WHERE 날짜 > now() - INTERVAL 1000 MINUTE;"

# %% [markdown]
# ## DB구조
#
# ### DB이름 : sensor
# ### 테이블이름: seonsor_xx (xx=44~52)
# ### 테이블 칼럼: 날짜, 온도, 습도, PM, CO2, TVOC
#
# ##### sensos_44: 거실
# ##### sensos_45: 거실 (공기청정기 옆에)
# ##### sensos_46: 안방
# ##### sensos_47: 가장 안쪽방
# ##### sensos_48: 중간방
# ##### sensor_49: 서재(가장아래)
# ##### sensor_50: 서재(아래)
# ##### sensor_51: 서재(중간)
# ##### sensor_52: 서재(맨위)
#
# ##### DB연결 오류시 바로 연락주시면 바로 유지보수

# %%
#Dataframe으로 데이터를 불러오기 위하여 sql사용 
df=pd.read_sql_query(sql,conn)
conn.close()

# %%
df
# Out:
#           id                  날짜      온도      습도     PM      CO2 TVOC
# 0     477363 2022-05-25 17:41:01  30.257  41.941  4.003    876.8    0
# 1     477364 2022-05-25 17:41:08  30.257  41.941  4.003    876.8    0
# 2     477365 2022-05-25 17:41:16  30.261  41.914  3.509  877.105    0
# 3     477366 2022-05-25 17:41:24  30.261  41.914  3.509  877.105    0
# 4     477367 2022-05-25 17:41:31  30.261  41.914  3.509  877.105    0
# ...      ...                 ...     ...     ...    ...      ...  ...
# 7814  485177 2022-05-26 10:20:23  30.251  41.995  5.516  714.939    0
# 7815  485178 2022-05-26 10:20:31  30.249  41.957  5.966  714.807    0
# 7816  485179 2022-05-26 10:20:38  30.249  41.957  5.966  714.807    0
# 7817  485180 2022-05-26 10:20:46  30.251  41.931  6.116  713.842    0
# 7818  485181 2022-05-26 10:20:54  30.251  41.931  6.116  713.842    0
#
# [7819 rows x 7 columns]

# %%
for i in range(len(df.CO2.values)):
    print(df.CO2.values[i])
# Out:
# 876.8
# 876.8
# 877.105
# 877.105
# 877.105
# 877.105
# 877.934
# 877.445
# 877.445
# 877.445
# 876.782
# 876.582
# 876.582
# 874.61
# 874.61
# 873.227
# 873.227
# 873.227
# 873.227
# 871.54
# 870.913
# 870.913
# 870.913
# 870.911
# 871.044
# 871.044
# 871.433
# 871.433
# 872.444
# 872.444
# 872.444
# 872.444
# 872.091
# 871.858
# 871.858
# 871.858
# 871.566
# 871.272
# 871.272
# 871.902
# 871.902
# 870.244
# 870.244
# 870.244
# 870.244
# 868.284
# 868.814
# 868.814
# 868.814
# 869.607
# 869.832
# 869.832
# 870.098
# 870.098
# 871.025
# 871.025
# 871.025
# 871.025
# 870.799
# 871.054
# 871.054
# 871.054
# 871.425
# 871.406
# 871.406
# 873.094
# 873.094
# 873.612
# 873.048
# 873.048
# 873.048
# 871.657
# 871.657
# 870.841
# 869.685
# 869.685
# 867.825
# 867.825
# 867.449
# 867.449
# 867.449
# 867.449
# 866.615
# 865.824
# 865.824
# 865.824
# 865.141
# 865.808
# 865.808
# 865.36
# 865.36
# 866.401
# 866.401
# 866.401
# 866.401
# 864.789
# 864.716
# 864.716
# 864.716
# 866.891
# ...

# %%
len(df.CO2.values)
# Out:
# 7819

# %% [markdown]
# * 최근데이터 전체 방 평균처리해서 보내주기 처음 보낸 후 generate로 계속 보내는 형식으로

# %%
conn = pymysql.connect(
user='room_test',
passwd='ehrnc64581',
#222.108.71.247(외부주소)
host='222.108.71.247',
#7656(외부포트)
port=7656,
db='sensor',
)

#
sql="SELECT * FROM sensor_45 WHERE 날짜 > now() - INTERVAL 1000 MINUTE;"

#
df=pd.read_sql_query(sql,conn)
conn.close()
df
# Out:
#           id                  날짜      온도      습도     PM      CO2 TVOC
# 0     491313 2022-05-26 23:25:54  28.996  43.774  2.779  747.591    0
# 1     491314 2022-05-26 23:26:02  28.996  43.774  2.779  747.591    0
# 2     491315 2022-05-26 23:26:09  28.996  43.774  2.779  747.591    0
# 3     491316 2022-05-26 23:26:18  28.991  43.815  2.695   747.89    0
# 4     491317 2022-05-26 23:26:25  28.993  43.804  2.676  747.482    0
# ...      ...                 ...     ...     ...    ...      ...  ...
# 7810  499123 2022-05-27 16:05:17  29.299  36.245  6.946  472.864    0
# 7811  499124 2022-05-27 16:05:24  29.284  36.145  7.013  472.403    0
# 7812  499125 2022-05-27 16:05:32  29.284  36.145  7.013  472.403    0
# 7813  499126 2022-05-27 16:05:39  29.284  36.145  7.013  472.403    0
# 7814  499127 2022-05-27 16:05:48  29.284  36.122  7.227  473.184    0
#
# [7815 rows x 7 columns]

# %%
sensor_list = ['44','45','46','47','48','49','50','51','53']
# sensor_list = ['44','45']
data_list = []
for i in sensor_list:
    conn = pymysql.connect(
    user='room_test',
    passwd='ehrnc64581',
    #222.108.71.247(외부주소)
    host='222.108.71.247',
    #7656(외부포트)
    port=7656,
    db='sensor',
    )

    #
    sql=f"SELECT * FROM sensor_{i} WHERE 날짜 > now() - INTERVAL 10 minute;"

    #
    df=pd.read_sql_query(sql,conn)
    conn.close()
    # df['time_index'] = pd.to_datetime(df['날짜']).dt.floor('min')
    df['co2'] = pd.to_numeric(df['CO2'])
    df['pm'] = pd.to_numeric(df['PM'])
    df['temp'] = pd.to_numeric(df['온도'])
    df['hum'] = pd.to_numeric(df['습도'])
    df = df.set_index('날짜').resample('1T',).mean()
    df['sensor'] = i
    data_list.append(df)
    print(df['co2'].values[-1])

data_concated = pd.concat(data_list,axis=0)
data_final = data_concated.groupby(['날짜'], as_index=True).mean()
# Out:
# 539.9034285714285
# 553.0382857142857
# 585.8801428571429
# 579.525125
# 543.5272857142857
# 503.97271428571423
# ...                            ...        ...        ...       ...         ...
# 2022-05-27 18:07:00  501064.750000  30.421548  34.738848  5.068405  488.588071
# 2022-05-27 18:08:00  501072.583333  30.431348  34.695735  4.978205  488.340182
# 2022-05-27 18:09:00  501080.333333  30.433982  34.785518  5.073006  488.389223
# 2022-05-27 18:10:00  501088.166667  30.437979  34.727104  4.847229  488.446854
# 2022-05-27 18:11:00  501093.583333  30.436778  34.686722  5.190722  489.004667
#
# ...

# %%
df.groupby(['반'], as_index=False).mean()

# %%
test_data = data_list[0]
for i in range(len(data_list)):
    test_data = test_data.merge(data_list[i], how="left",on = ['날짜'])
# Out:
# c:\Users\Go\miniconda3\envs\pro1\lib\site-packages\pandas\core\frame.py:9203: FutureWarning: Passing 'suffixes' which cause duplicate columns {'습도_x', 'id_x', '온도_x', 'CO2_x', 'PM_x'} in the result is deprecated and will raise a MergeError in a future version.
#   validate=validate,

# %%
printtest_data.iloc[0,:]
# Out:
# id_x      63677.000000
# 온도_x         32.142429
# 습도_x         35.168000
# PM_x          5.552000
# CO2_x       582.940143
# id_y      63677.000000
# 온도_y         32.142429
# 습도_y         35.168000
# PM_y          5.552000
# CO2_y       582.940143
# id_x     466283.500000
# 온도_x         29.994333
# 습도_x         40.225667
# PM_x          6.637667
# CO2_x       635.101333
# id_y     466972.000000
# 온도_y         29.961857
# 습도_y         40.369286
# PM_y          5.938143
# CO2_y       640.367714
# id_x     483375.500000
# 온도_x         29.560833
# 습도_x         40.972000
# PM_x          5.799333
# CO2_x       651.340333
# id_y     856748.000000
# 온도_y         31.358600
# 습도_y         37.659600
# PM_y          5.500200
# CO2_y       596.832200
# id       467096.000000
# 온도           33.234600
# 습도           31.884600
# PM            5.791400
# CO2         540.828600
# Name: 2022-05-24 18:04:00, dtype: float64

# %%
# data_list[0].set_index('날짜')[['CO2']].resample('1T',).mean()
data_list[0].set_index('날짜').resample('1T',).mean()
# Out:
#                           id         온도         습도        PM         CO2
# 날짜
# 2022-05-24 18:01:00  63653.5  32.141667  35.131833  5.669500  591.070667
# 2022-05-24 18:02:00  63660.5  32.142250  35.138250  5.500750  587.943250
# 2022-05-24 18:03:00  63668.0  32.145857  35.141571  5.466429  584.315000
# 2022-05-24 18:04:00  63676.0  32.140889  35.157667  5.572333  582.919333
# 2022-05-24 18:05:00  63684.0  32.131000  35.212429  6.017000  581.312143
# ...                      ...        ...        ...       ...         ...
# 2022-05-27 17:57:00  97160.0  31.368286  32.051143  4.652857  501.611000
# 2022-05-27 17:58:00  97167.5  31.373500  32.174625  5.141125  504.234500
# 2022-05-27 17:59:00  97175.5  31.369500  32.127750  5.460000  502.623500
# 2022-05-27 18:00:00  97183.5  31.365875  32.245125  4.665875  501.298625
# 2022-05-27 18:01:00  97188.0  31.375000  32.081000  4.506000  499.976000
#
# [4321 rows x 5 columns]

# %%
data_list[0].set_index('날짜')[['CO2']].resample('1T',)

# %%
data_list[0].set_index('time_index').resample('1T',)

# %%
data_list[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33540 entries, 0 to 33539
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          33540 non-null  int64
#  1   날짜          33540 non-null  datetime64[ns]
#  2   온도          33540 non-null  object
#  3   습도          33540 non-null  object
#  4   PM          33540 non-null  object
#  5   CO2         33540 non-null  object
#  6   TVOC        33540 non-null  object
#  7   time_index  33540 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(5)
# memory usage: 2.0+ MB

# %%
dd.to_datetime(data_list[1]['날짜']).dt.floor('min').compute()
# Out:
# 0       2022-05-24 17:19:00
# 1       2022-05-24 17:20:00
# 2       2022-05-24 17:20:00
# 3       2022-05-24 17:20:00
# 4       2022-05-24 17:20:00
#                 ...
# 33767   2022-05-27 17:19:00
# 33768   2022-05-27 17:19:00
# 33769   2022-05-27 17:19:00
# 33770   2022-05-27 17:19:00
# 33771   2022-05-27 17:19:00
# Length: 33772, dtype: datetime64[ns]

# %%
dd.to_datetime(data_list[1]['날짜']).compute()
# Out:
# 0       2022-05-24 17:19:55
# 1       2022-05-24 17:20:03
# 2       2022-05-24 17:20:11
# 3       2022-05-24 17:20:18
# 4       2022-05-24 17:20:26
#                 ...
# 33767   2022-05-27 17:19:14
# 33768   2022-05-27 17:19:21
# 33769   2022-05-27 17:19:29
# 33770   2022-05-27 17:19:37
# 33771   2022-05-27 17:19:44
# Length: 33772, dtype: datetime64[ns]

# %%
data_list[1]
# Out:
#            id                  날짜      온도      습도     PM      CO2 TVOC
# 0      465714 2022-05-24 16:51:43  30.004  40.138  6.747  651.568    0
# 1      465715 2022-05-24 16:51:51   29.99  40.157  6.803  652.488    0
# 2      465716 2022-05-24 16:51:58   29.99  40.157  6.803  652.488    0
# 3      465717 2022-05-24 16:52:06  29.994  40.136  6.314  653.127    0
# 4      465718 2022-05-24 16:52:14  29.994  40.136  6.314  653.127    0
# ...       ...                 ...     ...     ...    ...      ...  ...
# 33766  499480 2022-05-27 16:50:58  28.865   35.69  6.207  473.552    0
# 33767  499481 2022-05-27 16:51:06  28.898    35.7  6.357  473.828    0
# 33768  499482 2022-05-27 16:51:14  28.898    35.7  6.357  473.828    0
# 33769  499483 2022-05-27 16:51:21  28.898    35.7  6.357  473.828    0
# 33770  499484 2022-05-27 16:51:29  28.898    35.7  6.357  473.828    0
#
# [33771 rows x 7 columns]

# %%
import dask.dataframe as dd
import sqlalchemy
from sqlalchemy import create_engine

conn = pymysql.connect(
    user='room_test',
    passwd='ehrnc64581',
    #222.108.71.247(외부주소)
    host='222.108.71.247',
    #7656(외부포트)
    port=7656,
    db='sensor',
    )
dd.read_sql_table('sensor_47', conn,
                 npartitions=10, index_col='id')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37816\767773930.py in <module>
#      14
#      15 dd.read_sql_table('sensor_47', conn,
# ---> 16                  npartitions=10, index_col='id')
#
# c:\Users\Go\miniconda3\envs\pro1\lib\site-packages\dask\dataframe\io\sql.py in read_sql_table(table, uri, index_col, divisions, npartitions, limits, columns, bytes_per_chunk, head_rows, schema, meta, engine_kwargs, **kwargs)
#     108
#     109     engine_kwargs = {} if engine_kwargs is None else engine_kwargs
# --> 110     engine = sa.create_engine(uri, **engine_kwargs)
#     111     m = sa.MetaData()
#     112     if isinstance(table, str):
#
# <string> in create_engine(url, **kwargs)
#
# c:\Users\Go\miniconda3\envs\pro1\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     307                         stacklevel=3,
# ...

# %%
from sqlalchemy import create_engine
import MySQLdb

engine = create_engine("mysql://room_test:ehrnc64581@host/sensor")
Session = sessionmaker(bind=engine)

session = Session()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37816\3634568587.py in <module>
#       3
#       4 engine = create_engine("mysql://room_test:ehrnc64581@host/sensor")
# ----> 5 Session = sessionmaker(bind=engine)
#       6
#       7 session = Session()
#
# NameError: name 'sessionmaker' is not defined
